# %%
import numpy as np

# %%
import numpy as np

np.random.seed(0)
A=np.random.rand(200,200)
B=np.random.rand(200,200)
print(A)
print(B)
# Out:
# [[0.5488135  0.71518937 0.60276338 ... 0.25435648 0.05802916 0.43441663]
#  [0.31179588 0.69634349 0.37775184 ... 0.35670689 0.0163285  0.18523233]
#  [0.4012595  0.92929142 0.09961493 ... 0.47064895 0.37824517 0.97952693]
#  ...
#  [0.93359602 0.45489745 0.06166956 ... 0.53088099 0.56645427 0.98061971]
#  [0.88776958 0.50916905 0.15504342 ... 0.1632991  0.88517448 0.52466754]
#  [0.8301762  0.70833316 0.25812725 ... 0.58822388 0.42461491 0.9016327 ]]
# [[0.36925632 0.211326   0.47690477 ... 0.8618739  0.74437987 0.83849899]
#  [0.79396806 0.96428703 0.2389999  ... 0.95094366 0.37863591 0.47163332]
#  [0.44736762 0.89758608 0.30246692 ... 0.20321704 0.1855285  0.00824819]
#  ...
#  [0.1791466  0.32694537 0.15613618 ... 0.24662136 0.45418379 0.80146086]
#  [0.28820267 0.12738988 0.41164697 ... 0.36432601 0.43102553 0.70709125]
#  [0.22926219 0.66829409 0.26836332 ... 0.78412312 0.61925482 0.15752893]]

# %% [markdown]
# 2. Cálculo numérico y análisis
# ![image.png](attachment:image.png)

# %%
def f(x):
    return np.sin(x) + np.exp(-x/4)

y=f(5)
print("y:", y)
# Out:
# y: -0.6724194778029484

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=np.linspace(0,10,500)
h=[1]-x[0]

# %%
f_dif_aprox=(f(x+h)-f(x-h))/(2*h)

# %% [markdown]
# ![image.png](attachment:image.png)
